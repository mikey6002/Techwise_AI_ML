# %%
import pandas as pd

# %%
df = pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 990288  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 990289  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 990290  240410786  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330
# 990291  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 990292  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          7    Wilshire          784         1     510
# 1          1     Central          182         1     330
# 2          3   Southwest          356         1     480
# 3          9    Van Nuys          964         1     343
# 4          6   Hollywood          666         2     354
# ...      ...         ...          ...       ...     ...
# 990288     7    Wilshire          788         1     510
# 990289     1     Central          101         2     745
# 990290     4  Hollenbeck          421         1     341
# 990291     3   Southwest          358         1     230
# 990292     9    Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ... Status  \
# 0                                        VEHICLE - STOLEN  ...     AA
# 1                                   BURGLARY FROM VEHICLE  ...     IC
# 2                                           BIKE - STOLEN  ...     IC
# 3                SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4                                       THEFT OF IDENTITY  ...     IC
# ...                                                   ...  ...    ...
# 990288                                   VEHICLE - STOLEN  ...     IC
# 990289           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 990290  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 990291     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 990292                                   VEHICLE - STOLEN  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0       Adult Arrest    510.0    998.0       NaN      NaN
# 1        Invest Cont    330.0    998.0       NaN      NaN
# 2        Invest Cont    480.0      NaN       NaN      NaN
# 3        Invest Cont    343.0      NaN       NaN      NaN
# 4        Invest Cont    354.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 990288   Invest Cont    510.0      NaN       NaN      NaN
# 990289   Invest Cont    745.0      NaN       NaN      NaN
# 990290   Invest Cont    341.0      NaN       NaN      NaN
# 990291   Invest Cont    230.0      NaN       NaN      NaN
# 990292   Invest Cont    510.0      NaN       NaN      NaN
#
#                                         LOCATION  \
# 0        1900 S  LONGWOOD                     AV
# 1        1000 S  FLOWER                       ST
# 2        1400 W  37TH                         ST
# 3       14000    RIVERSIDE                    DR
# 4                              1900    TRANSIENT
# ...                                          ...
# 990288   4000 W  23RD                         ST
# 990289   1300 W  SUNSET                       BL
# 990290   1700    ALBION                       ST
# 990291           FLOWER                       ST
# 990292   6900    VESPER                       AV
#
#                            Cross Street      LAT       LON
# 0                                   NaN  34.0375 -118.3506
# 1                                   NaN  34.0444 -118.2628
# 2                                   NaN  34.0210 -118.3002
# 3                                   NaN  34.1576 -118.4387
# 4                                   NaN  34.0944 -118.3277
# ...                                 ...      ...       ...
# 990288                              NaN  34.0362 -118.3284
# 990289                              NaN  34.0685 -118.2460
# 990290                              NaN  34.0675 -118.2240
# 990291  JEFFERSON                    BL  34.0215 -118.2868
# 990292                              NaN  34.1961 -118.4510
#
# [990293 rows x 28 columns]

# %%
df.head() #Display the first few rows
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# 2                             BIKE - STOLEN  ...     IC   Invest Cont
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC   Invest Cont
# 4                         THEFT OF IDENTITY  ...     IC   Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    510.0    998.0       NaN      NaN
# 1    330.0    998.0       NaN      NaN
# 2    480.0      NaN       NaN      NaN
# 3    343.0      NaN       NaN      NaN
# 4    354.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 2   1400 W  37TH                         ST          NaN  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                         1900    TRANSIENT          NaN  34.0944 -118.3277
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990293 entries, 0 to 990292
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           990293 non-null  int64
#  1   Date Rptd       990293 non-null  object
#  2   DATE OCC        990293 non-null  object
#  3   TIME OCC        990293 non-null  int64
#  4   AREA            990293 non-null  int64
#  5   AREA NAME       990293 non-null  object
#  6   Rpt Dist No     990293 non-null  int64
#  7   Part 1-2        990293 non-null  int64
#  8   Crm Cd          990293 non-null  int64
#  9   Crm Cd Desc     990293 non-null  object
#  10  Mocodes         842641 non-null  object
#  11  Vict Age        990293 non-null  int64
#  12  Vict Sex        849515 non-null  object
#  13  Vict Descent    849504 non-null  object
#  14  Premis Cd       989970 non-null  float64
#  15  Premis Desc     989399 non-null  object
#  16  Weapon Used Cd  326547 non-null  float64
#  17  Weapon Desc     326547 non-null  object
#  18  Status          990292 non-null  object
#  19  Status Desc     990293 non-null  object
#  20  Crm Cd 1        990282 non-null  float64
#  21  Crm Cd 2        68957 non-null   float64
#  22  Crm Cd 3        2311 non-null    float64
#  23  Crm Cd 4        64 non-null      float64
#  24  LOCATION        990293 non-null  object
#  25  Cross Street    152641 non-null  object
#  26  LAT             990293 non-null  float64
#  27  LON             990293 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 211.5+ MB

# %%
print("\nInitial Dataset Summary:")
print(df.describe())
# Out:
# Initial Dataset Summary:
#               DR_NO                      Date Rptd           AREA  \
# count  8.202080e+05                         820208  820208.000000
# mean   2.201106e+08  2022-05-19 15:23:53.665606656      10.766640
# min    8.170000e+02            2020-01-01 00:00:00       1.000000
# 25%    2.107044e+08            2021-04-27 00:00:00       6.000000
# 50%    2.210025e+08            2022-06-09 00:00:00      11.000000
# 75%    2.310142e+08            2023-06-21 00:00:00      16.000000
# max    2.499289e+08            2024-10-27 00:00:00      21.000000
# std    1.297515e+07                            NaN       6.109888
#
#          Rpt Dist No       Part 1-2         Crm Cd       Vict Age  \
# count  820208.000000  820208.000000  820208.000000  820208.000000
# mean     1123.134446       1.357313     469.473325      38.299811
# min       101.000000       1.000000     110.000000      -4.000000
# 25%       622.000000       1.000000     330.000000      31.000000
# 50%      1147.000000       1.000000     420.000000      36.000000
# 75%      1637.000000       2.000000     624.000000      44.000000
# max      2199.000000       2.000000     956.000000     120.000000
# std       611.068807       0.479208     199.204980      13.362896
#
#            Premis Cd            LAT            LON      DayOfWeek  \
# count  820195.000000  820208.000000  820208.000000  820208.000000
# mean      302.307960      34.074924    -118.354993       2.865576
# min       101.000000      33.705900    -118.667600       0.000000
# 25%       101.000000      34.014600    -118.431200       1.000000
# 50%       203.000000      34.059500    -118.322600       3.000000
# 75%       501.000000      34.166700    -118.274000       5.000000
# max       976.000000      34.334300    -118.155400       6.000000
# std       219.115849       0.111594       0.104872       1.986441
#
#                Month           Year           Hour
# count  820208.000000  820208.000000  820208.000000
# mean        6.318531    2021.898794      13.221934
# min         1.000000    2020.000000       0.000000
# 25%         3.000000    2021.000000       9.000000
# 50%         6.000000    2022.000000      14.000000
# 75%         9.000000    2023.000000      19.000000
# max        12.000000    2024.000000      23.000000
# std         3.435892       1.295674       6.553907

# %%
print("\nMissing Values Count:")
print(df.isnull().sum())
# Out:
# Missing Values Count:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           147652
# Vict Age               0
# Vict Sex          140778
# Vict Descent      140789
# Premis Cd            323
# Premis Desc          894
# Weapon Used Cd    663746
# Weapon Desc       663746
# Status                 1
# Status Desc            0
# Crm Cd 1              11
# Crm Cd 2          921336
# Crm Cd 3          987982
# Crm Cd 4          990229
# LOCATION               0
# Cross Street      837652
# LAT                    0
# LON                    0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 990288  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 990289  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 990290  240410786  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330
# 990291  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 990292  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          7    Wilshire          784         1     510
# 1          1     Central          182         1     330
# 2          3   Southwest          356         1     480
# 3          9    Van Nuys          964         1     343
# 4          6   Hollywood          666         2     354
# ...      ...         ...          ...       ...     ...
# 990288     7    Wilshire          788         1     510
# 990289     1     Central          101         2     745
# 990290     4  Hollenbeck          421         1     341
# 990291     3   Southwest          358         1     230
# 990292     9    Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ... Status  \
# 0                                        VEHICLE - STOLEN  ...     AA
# 1                                   BURGLARY FROM VEHICLE  ...     IC
# 2                                           BIKE - STOLEN  ...     IC
# 3                SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4                                       THEFT OF IDENTITY  ...     IC
# ...                                                   ...  ...    ...
# 990288                                   VEHICLE - STOLEN  ...     IC
# 990289           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 990290  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 990291     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 990292                                   VEHICLE - STOLEN  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0       Adult Arrest    510.0    998.0       NaN      NaN
# 1        Invest Cont    330.0    998.0       NaN      NaN
# 2        Invest Cont    480.0      NaN       NaN      NaN
# 3        Invest Cont    343.0      NaN       NaN      NaN
# 4        Invest Cont    354.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 990288   Invest Cont    510.0      NaN       NaN      NaN
# 990289   Invest Cont    745.0      NaN       NaN      NaN
# 990290   Invest Cont    341.0      NaN       NaN      NaN
# 990291   Invest Cont    230.0      NaN       NaN      NaN
# 990292   Invest Cont    510.0      NaN       NaN      NaN
#
#                                         LOCATION  \
# 0        1900 S  LONGWOOD                     AV
# 1        1000 S  FLOWER                       ST
# 2        1400 W  37TH                         ST
# 3       14000    RIVERSIDE                    DR
# 4                              1900    TRANSIENT
# ...                                          ...
# 990288   4000 W  23RD                         ST
# 990289   1300 W  SUNSET                       BL
# 990290   1700    ALBION                       ST
# 990291           FLOWER                       ST
# 990292   6900    VESPER                       AV
#
#                            Cross Street      LAT       LON
# 0                                   NaN  34.0375 -118.3506
# 1                                   NaN  34.0444 -118.2628
# 2                                   NaN  34.0210 -118.3002
# 3                                   NaN  34.1576 -118.4387
# 4                                   NaN  34.0944 -118.3277
# ...                                 ...      ...       ...
# 990288                              NaN  34.0362 -118.3284
# 990289                              NaN  34.0685 -118.2460
# 990290                              NaN  34.0675 -118.2240
# 990291  JEFFERSON                    BL  34.0215 -118.2868
# 990292                              NaN  34.1961 -118.4510
#
# [990293 rows x 28 columns]

# %%
item_counts = df['Crm Cd Desc'].value_counts()

# Display the counts
print(item_counts)
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                           112502
# BATTERY - SIMPLE ASSAULT                                    74747
# BURGLARY FROM VEHICLE                                       61944
# THEFT OF IDENTITY                                           61413
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     60082
#                                                             ...
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              4
# TRAIN WRECKING                                                  1
# DRUNK ROLL - ATTEMPT                                            1
# Name: count, Length: 140, dtype: int64

# %%
# Drop rows where the description column contains vandalism,bikes stolen, profanity and harassment
df = df[~df['Crm Cd Desc'].str.contains("VANDALISM", case=False, na=False)]
df = df[~df['Crm Cd Desc'].str.contains("BIKE", case=False, na=False)]
df = df[~df['Crm Cd Desc'].str.contains("RESTRAINING ORDER", case=False, na=False)]
df = df[~df['Crm Cd Desc'].str.contains("LETTERS,LEWD - TELEPHONE CALLS, LEWD", case=False, na=False)]


# Drop rows that overlap or redudant
df = df[~df['Crm Cd Desc'].str.contains("THEFT PLAIN", case=False, na=False)]
df = df[~df['Crm Cd Desc'].str.contains("SHOPLIFTING-RELATED THEFTS", case=False, na=False)]
df = df[~df['Crm Cd Desc'].str.contains("Other Miscellaneous Crime", case=False, na=False)]


# Verify if rows removed
print(df['Crm Cd Desc'].value_counts())


#focus on crimes such as homicide, battery, assault, motor vehicle theft, and burglary, which are less likely to be optionally reported by residents
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                      112502
# BATTERY - SIMPLE ASSAULT                               74747
# BURGLARY FROM VEHICLE                                  61944
# THEFT OF IDENTITY                                      61413
# BURGLARY                                               57794
#                                                        ...
# GRAND THEFT / AUTO REPAIR                                  6
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)         5
# DISHONEST EMPLOYEE ATTEMPTED THEFT                         4
# TRAIN WRECKING                                             1
# DRUNK ROLL - ATTEMPT                                       1
# Name: count, Length: 129, dtype: int64

# %%
print(df.head()) #Display the first few rows
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
# 5  231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300    18
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
# 5  Southeast         1826         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC   Invest Cont
# 4                         THEFT OF IDENTITY  ...     IC   Invest Cont
# 5                         THEFT OF IDENTITY  ...     IC   Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    510.0    998.0       NaN      NaN
# 1    330.0    998.0       NaN      NaN
# 3    343.0      NaN       NaN      NaN
# 4    354.0      NaN       NaN      NaN
# 5    354.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                         1900    TRANSIENT          NaN  34.0944 -118.3277
# 5   9900    COMPTON                      AV          NaN  33.9467 -118.2463
#
# [5 rows x 28 columns]

# %%
# Drop rows where 'AREA NAME' is missing  and if data reported is missing
df = df[df['AREA NAME'].notna() & (df['AREA NAME'] != '')]
df = df[df['Date Rptd'].notna() & (df['AREA NAME'] != '')]
df = df[df['LOCATION'].notna() & (df['AREA NAME'] != '')]

# Verify if the rows have been deleted
print(f"Rows remaining after dropping missing 'AREA NAME': {len(df)}")
# Out:
# Rows remaining after dropping missing 'AREA NAME': 822181

# %%
#consistant date format
df['Date Rptd'] = pd.to_datetime(df['Date Rptd'])
df['DayOfWeek'] = df['Date Rptd'].dt.dayofweek
df['Month'] = df['Date Rptd'].dt.month
df['Year'] = df['Date Rptd'].dt.year
# Out:
# <ipython-input-13-e38e7c0ad7ed>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Rptd'] = pd.to_datetime(df['Date Rptd'])

# %%
median_age = df[df['Vict Age'] > 0]['Vict Age'].median() # Excludes 0 when calculating the median
df.loc[df['Vict Age'] == 0, 'Vict Age'] = median_age
print(f"Number of rows with Vict Age = 0: {len(df[df['Vict Age'] == 0])}")
print(f"Median Vict Age: {median_age}")
# Out:
# Number of rows with Vict Age = 0: 0
# Median Vict Age: 36.0

# %%
df = df.drop(columns=['Crm Cd 1','Crm Cd 2','Crm Cd 3','Crm Cd 4','Cross Street'])

# %%
# For LAT and LON, remove rows with coordinates outside the expected range
df = df[(df['LAT'] > 33.5) & (df['LAT'] < 34.5) & (df['LON'] < -118) & (df['LON'] > -119)]

# %%
df['Vict Sex'].fillna(df['Vict Sex'].mode()[0], inplace=True)
df['Vict Descent'].fillna(df['Vict Descent'].mode()[0], inplace=True)
df.isna().sum()
# Out:
# <ipython-input-17-d0b7c6f33317>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Vict Sex'].fillna(df['Vict Sex'].mode()[0], inplace=True)
# <ipython-input-17-d0b7c6f33317>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Vict Descent'].fillna(df['Vict Descent'].mode()[0], inplace=True)
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           144648
# Vict Age               0
# Vict Sex               0
# Vict Descent           0
# Premis Cd             13
# Premis Desc          562
# Weapon Used Cd    506202
# Weapon Desc       506202
# Status                 1
# Status Desc            0
# LOCATION               0
# LAT                    0
# LON                    0
# DayOfWeek              0
# Month                  0
# Year                   0
# dtype: int64

# %%
df['DATE OCC'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-18-9c8f55687984>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DATE OCC'].fillna(method='ffill', inplace=True)
# <ipython-input-18-9c8f55687984>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['DATE OCC'].fillna(method='ffill', inplace=True)

# %%
df['AREA NAME'].fillna(method='bfill', inplace=True)
# Out:
# <ipython-input-19-cf75b2eb5668>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AREA NAME'].fillna(method='bfill', inplace=True)
# <ipython-input-19-cf75b2eb5668>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['AREA NAME'].fillna(method='bfill', inplace=True)

# %%
df.dropna(subset=['DATE OCC', 'TIME OCC', 'AREA', 'Rpt Dist No'], inplace=True)

# %%
df['Status'].fillna('UNKNOWN', inplace=True)
# Out:
# <ipython-input-21-2c57a6f7ac44>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Status'].fillna('UNKNOWN', inplace=True)

# %%
df = df.drop(columns=['Mocodes', 'Premis Desc', 'Weapon Used Cd', 'Weapon Desc'])

# %%
#Histogram
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(22, 14))

numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

num_rows = (len(numerical_features) + 2) // 3
num_cols = 3

for i, feature in enumerate(numerical_features):
    plt.subplot(num_rows, num_cols, i + 1)
    sns.histplot(data=df, x=feature, kde=True)
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')


plt.tight_layout()

plt.show()

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
cleaned_df = pd.read_csv('cleaned_data.csv')
print(cleaned_df)
# Out:
#             DR_NO   Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0       190326475  2020-03-01  03/01/2020 12:00:00 AM      2130     7
# 1       200106753  2020-02-09  02/08/2020 12:00:00 AM      1800     1
# 2       200907217  2023-05-10  03/10/2020 12:00:00 AM      2037     9
# 3       220614831  2022-08-18  08/17/2020 12:00:00 AM      1200     6
# 4       231808869  2023-04-04  12/01/2020 12:00:00 AM      2300    18
# ...           ...         ...                     ...       ...   ...
# 820203  241414280  2024-10-16  10/16/2024 12:00:00 AM      1546    14
# 820204  240710284  2024-07-24  07/23/2024 12:00:00 AM      1400     7
# 820205  240410786  2024-10-14  10/11/2024 12:00:00 AM      2330     4
# 820206  240309674  2024-04-24  04/24/2024 12:00:00 AM      1500     3
# 820207  240910892  2024-08-13  08/12/2024 12:00:00 AM      2300     9
#
#          AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0         Wilshire          784         1     510
# 1          Central          182         1     330
# 2         Van Nuys          964         1     343
# 3        Hollywood          666         2     354
# 4        Southeast         1826         2     354
# ...            ...          ...       ...     ...
# 820203     Pacific         1489         1     341
# 820204    Wilshire          788         1     510
# 820205  Hollenbeck          421         1     341
# 820206   Southwest          358         1     230
# 820207    Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ...  Vict Descent  \
# 0                                        VEHICLE - STOLEN  ...             O
# 1                                   BURGLARY FROM VEHICLE  ...             O
# 2                SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...             O
# 3                                       THEFT OF IDENTITY  ...             H
# 4                                       THEFT OF IDENTITY  ...             H
# ...                                                   ...  ...           ...
# 820203  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...             H
# 820204                                   VEHICLE - STOLEN  ...             H
# 820205  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...             B
# 820206     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...             W
# 820207                                   VEHICLE - STOLEN  ...             H
#
#        Premis Cd Status   Status Desc  \
# 0          101.0     AA  Adult Arrest
# 1          128.0     IC   Invest Cont
# 2          405.0     IC   Invest Cont
# 3          102.0     IC   Invest Cont
# 4          501.0     IC   Invest Cont
# ...          ...    ...           ...
# 820203     223.0     IC   Invest Cont
# 820204     101.0     IC   Invest Cont
# 820205     210.0     IC   Invest Cont
# 820206     102.0     IC   Invest Cont
# 820207     108.0     IC   Invest Cont
#
#                                         LOCATION      LAT       LON  \
# 0        1900 S  LONGWOOD                     AV  34.0375 -118.3506
# 1        1000 S  FLOWER                       ST  34.0444 -118.2628
# 2       14000    RIVERSIDE                    DR  34.1576 -118.4387
# 3                              1900    TRANSIENT  34.0944 -118.3277
# 4        9900    COMPTON                      AV  33.9467 -118.2463
# ...                                          ...      ...       ...
# 820203   5200 W  98TH                         ST  33.9469 -118.3703
# 820204   4000 W  23RD                         ST  34.0362 -118.3284
# 820205   1700    ALBION                       ST  34.0675 -118.2240
# 820206           FLOWER                       ST  34.0215 -118.2868
# 820207   6900    VESPER                       AV  34.1961 -118.4510
#
#         DayOfWeek  Month  Year
# 0               6      3  2020
# 1               6      2  2020
# 2               2      5  2023
# 3               3      8  2022
# 4               1      4  2023
# ...           ...    ...   ...
# 820203          2     10  2024
# 820204          2      7  2024
# 820205          0     10  2024
# 820206          2      4  2024
# 820207          1      8  2024
#
# [820208 rows x 22 columns]

# %%
# extract hour from Time OCC
df['TIME OCC'] = df['TIME OCC'].astype(str).str.zfill(4)
df['Hour'] = df['TIME OCC'].str[:2].astype(int)
# Verify the transformation
print(df[['TIME OCC', 'Hour']].head())
# Out:
#   TIME OCC  Hour
# 0     2130    21
# 1     1800    18
# 3     2037    20
# 4     1200    12
# 5     2300    23

# %%
crime_by_hour = df['Hour'].value_counts().sort_index()

# Plot histogram
plt.figure(figsize=(10, 5))
plt.bar(crime_by_hour.index, crime_by_hour.values, color='blue', alpha=0.7)
plt.xlabel("Hour of the Day")
plt.ylabel("Number of Crimes")
plt.title("Crime Frequency by Hour of the Day (Military Time)")
plt.xticks(range(0, 24))  # Ensuring x-axis labels show all hours
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

#encoder object
label_encoder = LabelEncoder()

#categorical feature
cleaned_df['AREA NAME_Encoded'] = label_encoder.fit_transform(cleaned_df['AREA NAME'])

# %%
encoded_df = pd.get_dummies(cleaned_df, columns=['AREA NAME'], prefix=['AREA'])

# %% [markdown]
# Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
cleaned_df = pd.read_csv('cleaned_data.csv')

df['TIME OCC'] = df['TIME OCC'].astype(str).str.zfill(4)
df['Hour'] = df['TIME OCC'].str[:2].astype(int)  #hour

# crime counts per hour
crime_by_hour = df.groupby('Hour').size().reset_index(name='Crime_Count')


X = crime_by_hour[['Hour']]  #(Hour of the day)
y = crime_by_hour['Crime_Count']  # (Crime count)

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#predictions
y_pred = model.predict(X)

# %%
print(f"Intercept: {model.intercept_}")
print(f"Coefficient for Hour: {model.coef_[0]}")
print(f"R-squared Score: {r2_score(y, y_pred)}")
# Out:
# Intercept: 20051.893333333337
# Coefficient for Hour: 1228.1252173913042
# R-squared Score: 0.5483982803682856

# %%
# Plot actual vs predicted crime count
plt.figure(figsize=(10, 5))
sns.scatterplot(x=crime_by_hour['Hour'], y=crime_by_hour['Crime_Count'], color='blue', label='Actual Crime Count')
sns.lineplot(x=crime_by_hour['Hour'], y=y_pred, color='red', label='Linear Regression Fit')
plt.xlabel("Hour of the Day")
plt.ylabel("Number of Crimes")
plt.title("Crime Frequency by Hour of the Day ")
plt.xticks(range(0, 24))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
